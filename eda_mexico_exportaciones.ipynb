# %%
import pandas as pd

df = pd.read_csv('./datos/originales/mexico_exportaciones.csv')

print(df.shape)
# Out:
# (578, 24)

# %%
print(df.tail(5))
# Out:
#      Partida Aduanera Descripcion Partida Aduanera  \
# 573        1605610100              PEPINOS DE MAR.
# 574        1605610100              PEPINOS DE MAR.
# 575        1605610100              PEPINOS DE MAR.
# 576        1605610100              PEPINOS DE MAR.
# 577        1605610100              PEPINOS DE MAR.
#
#                                                 Aduana  \
# 573                                      TIJUANA- B.C.
# 574         GUADALAJARA, TLAJOMULCO DE ZUÑIGA, JALISCO
# 575                                      TIJUANA- B.C.
# 576                                      TIJUANA- B.C.
# 577  AEROPUERTO INTERNACIONAL DE LA CIUDAD DE MEXIC...
#
#                                 DUA       Fecha  Cod. Tributario  \
# 573  20240724-PPS1208244S2-4012622   24/07/2024  PPS1208244S2
# 574  20240729-GIN020110AG9-4005851   29/07/2024  GIN020110AG9
# 575  20240731-AGR9508171J9-4012685   31/07/2024  AGR9508171J9
# 576  20240731-AGR9508171J9-4012685   31/07/2024  AGR9508171J9
# ...

# %%
print(df.head(5))
# Out:
#    Partida Aduanera                       Descripcion Partida Aduanera  \
# 0         308199900  LOS DEMÁS PEPINOS DE MAR (STICHOPUS JAPONICUS,...
# 1         308199900  LOS DEMÁS PEPINOS DE MAR (STICHOPUS JAPONICUS,...
# 2         308199900  LOS DEMÁS PEPINOS DE MAR (STICHOPUS JAPONICUS,...
# 3         308199900  LOS DEMÁS PEPINOS DE MAR (STICHOPUS JAPONICUS,...
# 4         308199900  LOS DEMÁS PEPINOS DE MAR (STICHOPUS JAPONICUS,...
#
#                                               Aduana  \
# 0  AEROPUERTO INTERNACIONAL DE LA CIUDAD DE MEXIC...
# 1  AEROPUERTO INTERNACIONAL DE LA CIUDAD DE MEXIC...
# 2                                      TIJUANA- B.C.
# 3                                      TIJUANA- B.C.
# 4                                      TIJUANA- B.C.
#
#                               DUA       Fecha  Cod. Tributario  \
# 0  20190121-MBC180321661-9000114   21/01/2019  MBC180321661
# 1  20190122-MBC180321661-9000121   22/01/2019  MBC180321661
# ...

# %%
print(df.describe(include='all'))
# Out:
#         Partida Aduanera                       Descripcion Partida Aduanera  \
# count       5.780000e+02                                                578
# unique               NaN                                                  2
# top                  NaN  LOS DEMÁS PEPINOS DE MAR (STICHOPUS JAPONICUS,...
# freq                 NaN                                                294
# mean        9.456817e+08                                                NaN
# std         6.491698e+08                                                NaN
# min         3.081999e+08                                                NaN
# 25%         3.081999e+08                                                NaN
# 50%         3.081999e+08                                                NaN
# 75%         1.605610e+09                                                NaN
# max         1.605610e+09                                                NaN
#
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 578 entries, 0 to 577
# Data columns (total 24 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Partida Aduanera              578 non-null    int64
#  1   Descripcion Partida Aduanera  578 non-null    object
#  2   Aduana                        578 non-null    object
#  3   DUA                           578 non-null    object
#  4   Fecha                         578 non-null    object
#  5   Cod. Tributario               578 non-null    object
#  6   Exportador                    577 non-null    object
#  7   Ciudad Exportador             307 non-null    object
#  8   Dirección Exportador          558 non-null    object
#  9   Estado Exportador             268 non-null    object
#  10  Importador                    409 non-null    object
#  11  Ciudad Importador             115 non-null    object
# ...

# %%
ndf = df.drop(['Partida Aduanera', 'Descripcion Partida Aduanera', 'DUA','Ciudad Importador', 'Dirección Importador', 'Dirección Exportador', 'Ciudad Exportador', 'Estado Exportador', 'Descripción Comercial', 'Regimen'], axis=1)
print(ndf.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 578 entries, 0 to 577
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Aduana           578 non-null    object
#  1   Fecha            578 non-null    object
#  2   Cod. Tributario  578 non-null    object
#  3   Exportador       577 non-null    object
#  4   Importador       409 non-null    object
#  5   Qty 1            578 non-null    float64
#  6   Unid 1           578 non-null    object
#  7   Qty 2            578 non-null    float64
#  8   Unid 2           578 non-null    object
#  9   U$ FOB Tot       578 non-null    float64
#  10  U$ FOB Unit 1    578 non-null    float64
#  11  U$ FOB Unit 2    578 non-null    float64
#  12  País Destino     578 non-null    object
#  13  Vía              578 non-null    object
# dtypes: float64(5), object(9)
# memory usage: 63.3+ KB
# None

# %%
print(ndf.describe(include='object'))
# Out:
#                Aduana       Fecha  Cod. Tributario  \
# count             578         578              578
# unique             11         362               78
# top     TIJUANA- B.C.  16/06/2020  PPS1208244S2
# freq              302           8               48
#
#                                                Exportador  \
# count                                                 577
# unique                                                 77
# top     SOCIEDAD COOPERATIVA DE PRODUCCION PESQUERA SE...
# freq                                                   48
#
#                              Importador Unid 1 Unid 2    País Destino  \
# count                               409    578    578             578
# unique                              135      1      3               8
# top     PULPITO NEGRO WHOLESALE SEAFOOD     KG     KG  ESTADOS UNIDOS
# freq                                 23    578    474             323
#
#               Vía
# count         578
# unique          3
# ...

# %%
print(ndf.describe())
# Out:
#               Qty 1         Qty 2     U$ FOB Tot  U$ FOB Unit 1  U$ FOB Unit 2
# count    578.000000    578.000000     578.000000     578.000000     578.000000
# mean    1217.854239   2833.849567   27688.078478      46.211538      33.516993
# std     4191.690412   4468.610423   42580.211560      64.171677      49.714003
# min        0.000000      2.000000       0.000000       0.000000       0.000000
# 25%      200.000000    365.250000    4004.732500       8.000000       4.000000
# 50%      526.030000   1001.500000   11390.870000      20.706000      10.709000
# 75%     1200.000000   2693.750000   32831.232500      55.000000      41.750000
# max    95484.000000  29300.000000  368400.010000     402.877000     303.030000
