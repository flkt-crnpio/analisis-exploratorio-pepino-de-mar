# %%
import pandas as pd

df = pd.read_csv('../datos/originales/ecuador_exportaciones.csv')

print(df.shape)
# Out:
# (44, 51)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 51 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Partida Aduanera                    44 non-null     int64
#  1   Descripcion de la Partida Aduanera  44 non-null     object
#  2   Distrito Aduanero                   44 non-null     object
#  3   Reg. Aduana 1                       44 non-null     object
#  4   Reg. Aduana 2                       44 non-null     int64
#  5   Reg. Aduana 3                       44 non-null     int64
#  6   Fecha                               44 non-null     object
#  7   Cod. Tributario                     44 non-null     int64
#  8   Exportador                          44 non-null     object
#  9   Importador                          39 non-null     object
#  10  Qty                                 44 non-null     float64
# ...

# %%
print(df.head(5))
# Out:
#    Partida Aduanera Descripcion de la Partida Aduanera Distrito Aduanero  \
# 0        1605610000                     PEPINOS DE MAR     GQUIL - AEREO
# 1        1605610000                     PEPINOS DE MAR     GQUIL - AEREO
# 2        1605610000                     PEPINOS DE MAR     GQUIL - AEREO
# 3        1605610000                     PEPINOS DE MAR     GQUIL - AEREO
# 4        1605610000                     PEPINOS DE MAR     GQUIL - AEREO
#
#           Reg. Aduana 1  Reg. Aduana 2  Reg. Aduana 3       Fecha  \
# 0  019-2021-40-00805266              0              1  16/09/2021
# 1  019-2021-40-00873953              0              1  05/10/2021
# 2  019-2021-40-00946074              0              1  28/10/2021
# 3  019-2021-40-00946074              0              2  28/10/2021
# 4  019-2022-40-00064491              0              1  21/01/2022
#
#    Cod. Tributario                    Exportador                Importador  \
# ...

# %%
print(df.describe(include='all'))
# Out:
#         Partida Aduanera Descripcion de la Partida Aduanera Distrito Aduanero  \
# count       4.400000e+01                                 44                44
# unique               NaN                                  1                 3
# top                  NaN                     PEPINOS DE MAR     GQUIL - AEREO
# freq                 NaN                                 44                37
# mean        1.605610e+09                                NaN               NaN
# std         0.000000e+00                                NaN               NaN
# min         1.605610e+09                                NaN               NaN
# 25%         1.605610e+09                                NaN               NaN
# 50%         1.605610e+09                                NaN               NaN
# 75%         1.605610e+09                                NaN               NaN
# max         1.605610e+09                                NaN               NaN
#
# ...

# %%
ndf = df.drop(['Agente Maritimo','U$ CIF Und','U$ Seguro Und','U$ Flete Tot','U$ CFR Tot','U$ Seguro Tot','U$ CIF Tot','U$ FOB Und','U$ Flete Und','U$ CFR Und','Und','Qty 2','Unid 2','Kg Bruto','Kg Neto','Partida Aduanera','Reg. Aduana 1','Reg. Aduana 2','Reg. Aduana 3','Cod. Tributario','Agente de Carga','Tipo de Carga','Nave','Tipo de EXportacion'], axis=1)

print(ndf.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 27 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Descripcion de la Partida Aduanera  44 non-null     object
#  1   Distrito Aduanero                   44 non-null     object
#  2   Fecha                               44 non-null     object
#  3   Exportador                          44 non-null     object
#  4   Importador                          39 non-null     object
#  5   Qty                                 44 non-null     float64
#  6   U$ FOB Tot                          44 non-null     float64
#  7   U$ FOB Und 2                        22 non-null     float64
#  8   U$ Flete Und 2                      22 non-null     float64
#  9   U$ CFR Und 2                        22 non-null     float64
#  10  U$ Seguro Und 2                     22 non-null     float64
# ...

# %%
print(ndf.describe(include='object'))
# Out:
#        Descripcion de la Partida Aduanera Distrito Aduanero       Fecha  \
# count                                  44                44          44
# unique                                  1                 3          37
# top                        PEPINOS DE MAR     GQUIL - AEREO  08/07/2024
# freq                                   44                37           2
#
#           Exportador            Importador Und Unid 2       Pais de Origen  \
# count             44                    39  44     14                   44
# unique             6                    27   1      3                    1
# top     PACETOL S.A.  YUK LEUNG GLOBAL INC  KG     KG  ZONA FRANCA ECUADOR
# freq              20                     4  44     11                   44
#
#        Pais de Destino                       Puerto de Embarque  \
# count               44                                       39
# unique               5                                        9
# ...

# %%
print(ndf.describe())
# Out:
#                 Qty     U$ FOB Tot  U$ FOB Und 2  U$ Flete Und 2  \
# count     44.000000      44.000000     22.000000            22.0
# mean    2332.650909   94246.045455     74.541864             0.0
# std    10344.058308  113933.587594    105.155370             0.0
# min      127.000000    1135.000000      0.632000             0.0
# 25%      239.000000   13125.125000      5.000000             0.0
# 50%      642.000000   40209.750000     67.419500             0.0
# 75%     1061.000000  148619.500000     80.000000             0.0
# max    69264.000000  420000.000000    440.000000             0.0
#
#        U$ CFR Und 2  U$ Seguro Und 2  U$ CIF Und 2   U$ FOB kg  U$ Flete kg  \
# count     22.000000             22.0     22.000000   44.000000         44.0
# mean      74.541864              0.0     74.541864  121.201932          0.0
# std      105.155370              0.0    105.155370  100.161745          0.0
# ...

# %%
print(ndf.head(12))
